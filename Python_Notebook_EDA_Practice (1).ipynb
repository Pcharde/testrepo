# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv (r"C:\Users\pchar\Downloads\analysis-public-place-assaults-sexual-assaults-and-robberies-2015-csv.csv")
df.head(5)
# Out:
#    Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0      1               514102            Auckland Central West
# 1      2               573101  Willis Street-Cambridge Terrace
# 2      3               529700                 Hamilton Central
# 3      4               514103            Auckland Central East
# 4      5               591500                 Cathedral Square
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# 3                                375                      13250
# 4                                305                        570
#
#    Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 0                         346                          6.6
# 1                         539                         10.3
# ...

# %%
df.drop(' Rate_ratio_NZ_average_rate ', inplace=True, axis=1)
df.head(10)
# Out:
#    Area_unit_2013_code             Area_unit_2013_label  \
# 0               514102            Auckland Central West
# 1               573101  Willis Street-Cambridge Terrace
# 2               529700                 Hamilton Central
# 3               514103            Auckland Central East
# 4               591500                 Cathedral Square
# 5               514101             Auckland Harbourside
# 6               524604                  Manukau Central
# 7               562800         Palmerston North Central
# 8               540410                           Kuirau
# 9               538201                 Tauranga Central
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# 3                                375                      13250
# ...

# %%
df.drop(["Urban_area_2013_code", "Urban_area_type", "Territorial_authority_area_2013_code", "Region_2013_code"],inplace = True, axis = 1)
df.head(5)
# Out:
#    Area_unit_2013_code             Area_unit_2013_label  \
# 0               514102            Auckland Central West
# 1               573101  Willis Street-Cambridge Terrace
# 2               529700                 Hamilton Central
# 3               514103            Auckland Central East
# 4               591500                 Cathedral Square
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# 3                                375                      13250
# 4                                305                        570
#
#    Rate_per_10000_population   Urban_area_2013_label  \
# 0                         346  Central Auckland Zone
# 1                         539        Wellington Zone
# 2                       1,199          Hamilton Zone
# ...

# %%
df.shape
# Out:
# (2020, 8)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 8)

# %%
df.count() # Used to count the number of rows
# Out:
# Area_unit_2013_code                      2020
# Area_unit_2013_label                     2020
# Victimisations_calendar_year_2015        2020
# Population_mid_point_2015                2020
#  Rate_per_10000_population               2020
# Urban_area_2013_label                    2020
# Territorial_authority_area_2013_label    2020
# Region_2013_label                        2020
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#    Area_unit_2013_code             Area_unit_2013_label  \
# 0               514102            Auckland Central West
# 1               573101  Willis Street-Cambridge Terrace
# 2               529700                 Hamilton Central
# 3               514103            Auckland Central East
# 4               591500                 Cathedral Square
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# 3                                375                      13250
# 4                                305                        570
#
#    Rate_per_10000_population   Urban_area_2013_label  \
# 0                         346  Central Auckland Zone
# 1                         539        Wellington Zone
# 2                       1,199          Hamilton Zone
# ...

# %%
print(df.isnull().sum()) # Checking the Null values/ missing Values
# Out:
# Area_unit_2013_code                      0
# Area_unit_2013_label                     0
# Victimisations_calendar_year_2015        0
# Population_mid_point_2015                0
#  Rate_per_10000_population               0
# Urban_area_2013_label                    0
# Territorial_authority_area_2013_label    0
# Region_2013_label                        0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Area_unit_2013_code                      2020
# Area_unit_2013_label                     2020
# Victimisations_calendar_year_2015        2020
# Population_mid_point_2015                2020
#  Rate_per_10000_population               2020
# Urban_area_2013_label                    2020
# Territorial_authority_area_2013_label    2020
# Region_2013_label                        2020
# dtype: int64

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# Area_unit_2013_code                      0
# Area_unit_2013_label                     0
# Victimisations_calendar_year_2015        0
# Population_mid_point_2015                0
#  Rate_per_10000_population               0
# Urban_area_2013_label                    0
# Territorial_authority_area_2013_label    0
# Region_2013_label                        0
# dtype: int64
